# %%
# Regrular expresstion
import re
"""Identifier:
\d any number
\D anything but a number
\s space
\S anything but space
\w any charecters
\W anything but a character
. any  character, except for newline
\b the whitespace around word
\. a period

Modifier:

{1, 3} we're expecting for example \d{1-3}
+ Match 1 or more
? Match 0 or 1
* Match 0 or more
$ Match end of the string 
^ Matching the beginning of a string
| either or
[] range or "varience"
{x} expecting "x"  amount


White space charecter
\n new line
\s space 
\t tab
\e esacpe
\f form feed
\r return

"""

# %%
import re

# %%
example_string = """ Jessca is 15 year old, and Daniel is 27 years old.
Edward is 97, and his grandfather, Oscar, is 102. """

# %%
ages =  re.findall(r'\d{1,3}', example_string)
names =  re.findall(r'[A-Z][a-z]*', example_string)

# %%
print(ages, names)
# Out:
# ['15', '27', '97', '102'] ['Jessca', 'Daniel', 'Edward', 'Oscar']

# %%
ageDict = {}

x = 0
for eachName in names:
    ageDict[eachName] = ages[x]
    x+=1

# %%
print(ageDict)
# Out:
# {'Jessca': '15', 'Daniel': '27', 'Edward': '97', 'Oscar': '102'}

# %%
potato_df["WEIGHT_GRAM"] = potato_df["PROD_NAME"].str.extract(r'\b{1, 3}*', expand = True)
potato_df.head()

# %%
potato_df["PROD_NAME"] = potato_df["PROD_NAME"].apply( lambda x : re.findall(r'/d{1, 3}'), potato_df["PROD_NAME"])

# %%
potato_df["PROD_NAME"] = filter(lambda x : x.str.isalpha(), potato_df["PROD_NAME"])

# %%
potato_df["PROD_NAME"] = re.findall(r'\b\d+\b', potato_df["PROD_NAME"])(r'/b{1,3}')

# %%
potato_df["WEIGHT_GRAM"] = potato_df.PROD_NAME.re.sub(r'/d{1,3}').astype(str)
